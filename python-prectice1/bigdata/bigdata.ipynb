# %%
import os, re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

os.chdir(r'D:\python-prectice1\prectice_python\bigdata')
df = pd.read_csv('information.csv')
print(df)
df2 = df[(df['age']<100) & (df['birth']<1232)]
print(df2)
print(df['name'].value_counts())

df.sort_values(by='age', ascending=False).loc[:,['name','sex']]
df.sort_values(by='birth', ascending=False).loc[:,['name','birth']]
df.sort_values(by='bloodtype', ascending=False).loc[:,['name','bloodtype']]
print(df2.groupby('sex').sum())

age_total = {'honggi': 64,
             'junggi': 60,
             'subok': 59,
             'gyunghee': 59,
             'gyungsuk': 59,
             'minhwa': 56,
             'hyungseok': 53,
             'soyoung': 52,
             'yunhee': 34,
             'jonghwa': 33,
             'yangwon': 29,
             'jongsung': 29,
             'unhee': 29,
             'heeju': 25,
             'haeju': 25,
             'jun': 23}
group_data = list(age_total.values())
group_names = list(age_total.keys())
group_mean = np.mean(group_data)
fig, ax = plt.subplots()
ax.barh(group_names, group_data)

birth_total = {'minhwa': 1221,
               'subok' : 1113,
               'yunhee' : 1007,
               'yangwon' : 924,
               'haeju' : 922,
               'gyunghee' : 824,
               'junggi' : 707,
               'hyungseok' : 701,
               'heeju' : 626,
               'gyungsuk' : 602,
               'jun' : 530,
               'jonghwa' : 417,
               'jongsung' : 325,
               'soyoung' : 220,
               'honggi' : 104,
               'unhee' : 11}

group_data2 = list(birth_total.values())
group_names2 = list(birth_total.keys())
group_mean2 = np.mean(group_data2)
fig, ax = plt.subplots()
ax.barh(group_names2, group_data2)

bloodtype_total = { 'gyungsuk' : 'a',
                    'junggi' : 'a',
                    'subok' : 'ab',
                    'jonghwa' : 'ab',
                    'honggi' : 'ab',
                    'gyunghee' : 'ab',
                    'yangwon' : 'b',
                    'heeju' : 'b',
                    'jun' : 'b',
                    'unhee' : 'b',
                    'yunhee' : 'b',
                    'soyoung' : 'b',
                    'minhwa' : 'o',
                    'haeju' : 'o',
                    'jongsung' : 'o',
                    'hyungseok' : 'o'}

group_data = list(bloodtype_total.values())
group_names = list(bloodtype_total.keys())
group_mean = np.mean(group_data2)
fig, ax = plt.subplots()
ax.barh(group_names2, group_data2)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[13], line 7
#       4 import matplotlib.pyplot as plt
#       6 os.chdir(r'D:\python-prectice1\prectice_python\bigdata')
# ----> 7 df = pd.read_csv('information.csv')
#       8 print(df)
#       9 df2 = df[(df['age']<100) & (df['birth']<1232)]
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# CSV 파일 읽기
df = pd.read_csv('information.csv')

# 데이터프레임 출력
print(df)

# 나이와 생일 조건으로 필터링된 데이터프레임 생성
df2 = df[(df['age'] < 100) & (df['birth'] < 1232)]
print(df2)

# 이름별 빈도수 출력
print(df['name'].value_counts())

# 나이 기준으로 정렬된 데이터프레임에서 이름과 성별 출력
print(df.sort_values(by='age', ascending=False).loc[:, ['name', 'sex']])

# 생일 기준으로 정렬된 데이터프레임에서 이름과 생일 출력
print(df.sort_values(by='birth', ascending=False).loc[:, ['name', 'birth']])

# 혈액형 기준으로 정렬된 데이터프레임에서 이름과 혈액형 출력
print(df.sort_values(by='blood type', ascending=False).loc[:, ['name', 'blood type']])

# 성별로 그룹화된 데이터프레임 합계 출력
print(df2.groupby('sex').sum())

# 나이 막대 그래프 생성
age_total = {'honggi': 64, 'junggi': 60, 'subok': 59, 'gyunghee': 59, 'gyungsuk': 59, 'minhwa': 56,
             'hyungseok': 53, 'soyoung': 52, 'yunhee': 34, 'jonghwa': 33, 'yangwon': 29, 'jongsung': 29,
             'unhee': 29, 'heeju': 25, 'haeju': 25, 'jun': 23}
group_data = list(age_total.values())
group_names = list(age_total.keys())
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
plt.show()

# 생일 막대 그래프 생성
birth_total = {'minhwa': 1221, 'subok': 1113, 'yunhee': 1007, 'yangwon': 924, 'haeju': 922,
               'gyunghee': 824, 'junggi': 707, 'hyungseok': 701, 'heeju': 626, 'gyungsuk': 602,
               'jun': 530, 'jonghwa': 417, 'jongsung': 325, 'soyoung': 220, 'honggi': 104, 'unhee': 11}
group_data2 = list(birth_total.values())
group_names2 = list(birth_total.keys())
fig, ax = plt.subplots()
ax.barh(group_names2, group_data2)
plt.show()

# 혈액형 막대 그래프 생성
bloodtype_total = {'gyungsuk': 'a', 'junggi': 'a', 'subok': 'ab', 'jonghwa': 'ab', 'honggi': 'ab',
                   'gyunghee': 'ab', 'yangwon': 'b', 'heeju': 'b', 'jun': 'b', 'unhee': 'b',
                   'yunhee': 'b', 'soyoung': 'b', 'minhwa': 'o', 'haeju': 'o', 'jongsung': 'o',
                   'hyungseok': 'o'}
group_data3 = list(bloodtype_total.values())
group_names3 = list(bloodtype_total.keys())
fig, ax = plt.subplots()
ax.barh(group_names3, group_data3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       5 # CSV 파일 읽기
# ----> 6 df = pd.read_csv('information.csv')
#       8 # 데이터프레임 출력
#       9 print(df)
#
# ...
